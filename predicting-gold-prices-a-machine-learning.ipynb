# %% [markdown]
# <div style='border: 3px solid #4682B4; background-color:#F0F8FF; padding:20px; text-align: center; border-radius: 15px; animation: slideIn 1.5s; box-shadow: 0 0 20px rgba(0, 0, 0, 0.1); position: relative;'>
#     <p style="font-family: 'Arial', sans-serif; font-size: 18px; text-align: center; color:#2F4F4F;">
#         <img src="https://media.licdn.com/dms/image/v2/D4D03AQGc0oHpRuLDTw/profile-displayphoto-shrink_800_800/profile-displayphoto-shrink_800_800/0/1683480985092?e=1738195200&v=beta&t=oiGZYklecJZVoLXBRE0PYjedxGiiSQ1iJJiid7GjyFc" alt="Profile Picture" style="width: 180px; height: 180px; border-radius: 50%; box-shadow: 0 0 15px rgba(0,0,0,0.3); margin-bottom: 20px;">
#         <br>💜 <span style="animation: colorChange 3s infinite;">Hey Friends!</span> 👋
#         <br>
#         I'm <b>Zaid Nserat</b>.
#         <br> Skilled in <b>Python</b>, <b>Data Science</b>, and <b>Machine Learning</b>,
#         <br> An aspiring <b>Artificial Intelligence</b> expert.
#         <br><br>
#         <div style="animation: float 3s infinite; display: inline-block;">
#             Let's connect!
#         </div>
#         <br><br>
#         <a href="https://www.kaggle.com/zaed2003" target="_blank" style="margin: 0 10px; color: #2F4F4F; transition: color 0.3s;"><i class="fab fa-kaggle fa-2x"></i></a>
#         <a href="https://www.linkedin.com/in/zaid-nserat-192a7a275/" target="_blank" style="margin: 0 10px; color: #2F4F4F; transition: color 0.3s;"><i class="fab fa-linkedin fa-2x"></i></a>
#     </p>
#     <div class="corner-decor top-left"></div>
#     <div class="corner-decor top-right"></div>
#     <div class="corner-decor bottom-left"></div>
#     <div class="corner-decor bottom-right"></div>
# </div>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">
#
# <style>
#     @keyframes rotateIn {
#         0% {
#             transform: rotate(0deg);
#         }
#         50% {
#             transform: rotate(180deg);
#         }
#         100% {
#             transform: rotate(360deg);
#         }
#     }
#
#     @keyframes slideIn {
#         from {
#             transform: translateX(-100%);
#             opacity: 0;
#         }
#         to {
#             transform: translateX(0);
#             opacity: 1;
#         }
#     }
#
#     @keyframes shake {
#         0%, 100% {
#             transform: translateX(0);
#         }
#         25%, 75% {
#             transform: translateX(-5px);
#         }
#         50% {
#             transform: translateX(5px);
#         }
#     }
#
#     a:hover {
#         color: #4682B4 !important;
#         animation: shake 0.5s;
#     }
#
#     @keyframes colorChange {
#         0% {
#             color: #2F4F4F;
#         }
#         50% {
#             color: #4682B4;
#         }
#         100% {
#             color: #2F4F4F;
#         }
#     }
#
#     @keyframes float {
#         0% {
#             transform: translateY(0);
#         }
#         50% {
#             transform: translateY(-10px);
#         }
#         100% {
#             transform: translateY(0);
#         }
#     }
#
#     .corner-decor {
#         width: 40px;
#         height: 40px;
#         position: absolute;
#         background-image: url('https://cdn.pixabay.com/photo/2016/04/01/09/56/pink-1299206_1280.png');
#         background-size: cover;
#         border-radius: 50%;
#         box-shadow: 0 0 10px rgba(0, 0, 0, 0.3);
#         animation: rotateIn 5s infinite;
#     }
#
#     .top-left {
#         top: -20px;
#         left: -20px;
#     }
#
#     .top-right {
#         top: -20px;
#         right: -20px;
#     }
#
#     .bottom-left {
#         bottom: -20px;
#         left: -20px;
#     }
#
#     .bottom-right {
#         bottom: -20px;
#         right: -20px;
#     }
# </style>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #f7fafc, #e2e8f0); padding: 25px; border: 2px solid #4a5568; border-radius: 20px; box-shadow: 4px 6px 10px rgba(0, 0, 0, 0.1); line-height: 1.8em; font-family: 'Arial', sans-serif;">
#     <h2 style="color: #2d3748; font-size: 24px; text-transform: uppercase; letter-spacing: 1px; text-align: center; margin-bottom: 20px; border-bottom: 2px solid #2d3748; display: inline-block; padding-bottom: 5px;">🚀 Project Objectives</h2>
#     <p style="font-size: 18px; margin-top: 15px; text-align: justify; color: #2d3748;">
#         <ul style="list-style-type: none; padding-left: 0;">
#             <li style="margin-bottom: 15px;">
#                 <span style="font-weight: bold; color: #4a5568;">1. Gold Price Prediction:</span> Develop a machine learning model to accurately predict gold prices based on financial features such as <code>SPX</code>, <code>GLD</code>, <code>USO</code>, <code>SLV</code>, and <code>EUR/USD</code>.
#             </li>
#             <li style="margin-bottom: 15px;">
#                 <span style="font-weight: bold; color: #4a5568;">2. Exploratory Data Analysis (EDA):</span> Conduct a detailed analysis to explore feature distributions, identify correlations, and visualize relationships between predictors and the target variable (gold price).
#             </li>
#             <li style="margin-bottom: 15px;">
#                 <span style="font-weight: bold; color: #4a5568;">3. Feature Engineering:</span> Preprocess data by handling missing values, scaling, and creating derived features (e.g., moving averages or volatility measures) to improve predictive accuracy.
#             </li>
#             <li style="margin-bottom: 15px;">
#                 <span style="font-weight: bold; color: #4a5568;">4. Model Development:</span> Experiment with various regression models, including Random Forest, XGBoost, and Linear Regression, to identify the best-performing approach for gold price prediction.
#             </li>
#             <li>
#                 <span style="font-weight: bold; color: #4a5568;">5. Insights and Recommendations:</span> Provide actionable insights on the key factors influencing gold prices and offer strategies for future forecasting.
#             </li>
#         </ul>
#     </p>
# </div>

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #ffffff; text-align: center; margin: 0; text-shadow: 3px 3px 5px rgba(0, 0, 0, 0.4); background-color: #1a202c; padding: 20px; border-radius: 20px; border: 7px solid #4a90e2; width: 95%;">
#   <span style="font-weight: bold; color: #ff4500; animation: pulse 2s infinite;">✨ Gold Price 📈</span>
#   <span style="font-style: italic; color: #ffcc00; animation: pulse 2s infinite;"> Prediction Project </span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.1);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %% [markdown]
# <div style="text-align:center">
#     <img src="https://d2tpnh780x5es.cloudfront.net/rebrand-prod/oftlvjvq/gold-price-predictions.png" alt="alt text">
# </div>

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <div style="font-family: 'Amiri', serif; font-size: 3rem; color: #ffffff; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #4a5568; padding: 20px; border-radius: 20px; border: 7px solid #38a169; width: 95%;">
#   <p style="margin: 0; font-weight: bold; color: #f6e05e; animation: pulse 2s infinite;">📊 Import Data from Kaggle</p>
#   <a href="https://www.kaggle.com/datasets/hosammhmdali/gold-price-dataset/code" target="_blank"
#      style="display: inline-block; font-size: 1.5rem; color: #81e6d9; font-weight: bold; text-decoration: none; margin-top: 20px; padding: 10px 20px; border-radius: 10px; border: 2px solid #38a169; background-color: #2d3748; text-shadow: none; transition: background-color 0.3s ease, color 0.3s ease;">
#     📂 View Dataset on Kaggle
#   </a>
# </div>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %% [markdown]
# <div style="font-family: 'Amiri', serif; font-size: 3rem; color: #ffffff; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #1e293b; padding: 20px; border-radius: 20px; border: 7px solid #f6ad55; width: 95%;">
#   <span style="font-weight: bold; color: #38b2ac; animation: pulse 2s infinite;">Step 1: Importing</span>
#   <span style="font-style: italic; color: #fbb6ce; animation: pulse 2s infinite;"> Libraries 📚</span>
# </div>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
from plotly.offline import iplot
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import missingno as mse
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,BaggingRegressor,AdaBoostRegressor
from sklearn.metrics import r2_score ,mean_squared_error

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #ffffff; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #2d3748; padding: 20px; border-radius: 20px; border: 7px solid #38a169; width: 95%;">
#   <span style="font-weight: bold; color: #f6e05e; animation: pulse 2s infinite;">Step 2: Read</span>
#   <span style="font-style: italic; color: #63b3ed; animation: pulse 2s infinite;"> Data 📖</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
df=pd.read_csv('/home/hadoop/docker_file/gld_price_data.csv')
df
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
# Display the first 5 rows 
df.head().style.background_gradient('autumn_r')
# Out:
# <style type="text/css">
# #T_fad70_row0_col1, #T_fad70_row0_col3, #T_fad70_row1_col1, #T_fad70_row4_col2, #T_fad70_row4_col4, #T_fad70_row4_col5 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_fad70_row0_col2 {
#   background-color: #fff400;
#   color: #000000;
# }
# #T_fad70_row0_col4 {
#   background-color: #ffc300;
#   color: #000000;
# }
# #T_fad70_row0_col5 {
#   background-color: #fff600;
#   color: #000000;
# }
# #T_fad70_row1_col2 {
#   background-color: #ff9a00;
#   color: #000000;
# }
# #T_fad70_row1_col3 {
#   background-color: #ff0800;
#   color: #f1f1f1;
# }
# #T_fad70_row1_col4 {
#   background-color: #ff9100;
#   color: #000000;
# }
# #T_fad70_row1_col5 {
#   background-color: #ffee00;
#   color: #000000;
# }
# #T_fad70_row2_col1 {
#   background-color: #ff9f00;
#   color: #000000;
# }
# #T_fad70_row2_col2 {
#   background-color: #ffd200;
#   color: #000000;
# }
# #T_fad70_row2_col3 {
#   background-color: #ff6300;
#   color: #f1f1f1;
# }
# ...

# %%
# Display the last 5 rows 
df.tail(5).style.background_gradient(cmap='seismic')
# Out:
# <style type="text/css">
# #T_2a9a9_row0_col1, #T_2a9a9_row0_col3, #T_2a9a9_row4_col2, #T_2a9a9_row4_col4, #T_2a9a9_row4_col5 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# #T_2a9a9_row0_col2 {
#   background-color: #f20000;
#   color: #f1f1f1;
# }
# #T_2a9a9_row0_col4 {
#   background-color: #0000d6;
#   color: #f1f1f1;
# }
# #T_2a9a9_row0_col5 {
#   background-color: #b5b5ff;
#   color: #000000;
# }
# #T_2a9a9_row1_col1 {
#   background-color: #c5c5ff;
#   color: #000000;
# }
# #T_2a9a9_row1_col2 {
#   background-color: #ff4949;
#   color: #f1f1f1;
# }
# #T_2a9a9_row1_col3 {
#   background-color: #ba0000;
#   color: #f1f1f1;
# }
# #T_2a9a9_row1_col4 {
#   background-color: #0d0dff;
#   color: #f1f1f1;
# }
# #T_2a9a9_row1_col5 {
#   background-color: #0000fa;
#   color: #f1f1f1;
# }
# #T_2a9a9_row2_col1, #T_2a9a9_row2_col5 {
#   background-color: #be0000;
#   color: #f1f1f1;
# }
# ...

# %%
#Display the sample 5 rows
df.sample(5).style.background_gradient(cmap='gist_rainbow')
# Out:
# <style type="text/css">
# #T_c2cc7_row0_col1 {
#   background-color: #26ff00;
#   color: #000000;
# }
# #T_c2cc7_row0_col2 {
#   background-color: #ffe000;
#   color: #000000;
# }
# #T_c2cc7_row0_col3, #T_c2cc7_row0_col5, #T_c2cc7_row1_col4, #T_c2cc7_row2_col1, #T_c2cc7_row2_col2 {
#   background-color: #ff0029;
#   color: #f1f1f1;
# }
# #T_c2cc7_row0_col4 {
#   background-color: #c8ff00;
#   color: #000000;
# }
# #T_c2cc7_row1_col1, #T_c2cc7_row2_col3 {
#   background-color: #7000ff;
#   color: #f1f1f1;
# }
# #T_c2cc7_row1_col2, #T_c2cc7_row2_col5, #T_c2cc7_row3_col3, #T_c2cc7_row3_col4, #T_c2cc7_row3_col5, #T_c2cc7_row4_col1 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_c2cc7_row1_col3 {
#   background-color: #ff0d00;
#   color: #f1f1f1;
# }
# #T_c2cc7_row1_col5 {
#   background-color: #00ff66;
#   color: #000000;
# }
# #T_c2cc7_row2_col4 {
#   background-color: #0012ff;
#   color: #f1f1f1;
# }
# #T_c2cc7_row3_col1 {
#   background-color: #ffa900;
# ...

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #ffffff; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #1a202c; padding: 20px; border-radius: 20px; border: 7px solid #4fd1c5; width: 95%;">
#   <span style="font-weight: bold; color: #f6ad55; animation: pulse 2s infinite;">Step 3: Let's Get</span>
#   <span style="font-style: italic; color: #90cdf4; animation: pulse 2s infinite;">Quick Overview 🧐😉</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
print(df.shape)
print(f"the number of rows in data {df.shape[0]}".title())
print(f"the number of features in data {df.shape[1]}".title())
# Out:
# (2290, 6)
# The Number Of Rows In Data 2290
# The Number Of Features In Data 6

# %%
#information data :
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %% [markdown]
# ## <p style="background-color: #4a90e2; font-family: Calibri; color: #ffffff; font-size: 140%; text-align: center; border-radius: 30px;">Data Description 💡</p>
#
# <div style="background-color: #1e293b; padding: 15px; border-radius: 15px;">
#     <table style="width: 100%; border-collapse: collapse; text-align: center; color: #ffffff; font-family: Arial, sans-serif;">
#         <thead style="background-color: #4a90e2; color: #ffffff;">
#             <tr>
#                 <th style="padding: 10px; border: 1px solid #2d3748;">Column Name</th>
#                 <th style="padding: 10px; border: 1px solid #2d3748;">Data Type</th>
#                 <th style="padding: 10px; border: 1px solid #2d3748;">Unique Values</th>
#                 <th style="padding: 10px; border: 1px solid #2d3748;">Null Count</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff6347;">Date</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #00ffff;">object</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ffd700;">2290</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff4500;">0</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff6347;">SPX</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #00ffff;">float64</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ffd700;">2290</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff4500;">0</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff6347;">GLD</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #00ffff;">float64</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ffd700;">2290</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff4500;">0</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff6347;">USO</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #00ffff;">float64</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ffd700;">2290</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff4500;">0</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff6347;">SLV</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #00ffff;">float64</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ffd700;">2290</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff4500;">0</td>
#             </tr>
#             <tr>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff6347;">EUR/USD</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #00ffff;">float64</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ffd700;">2290</td>
#                 <td style="border: 1px solid #2d3748; padding: 10px; color: #ff4500;">0</td>
#             </tr>
#         </tbody>
#     </table>
# </div>

# %%
#Description of number data
df.describe().style.background_gradient(cmap='RdYlBu_r')
# Out:
# <style type="text/css">
# #T_f3a5f_row0_col0 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_f3a5f_row0_col1, #T_f3a5f_row0_col2, #T_f3a5f_row0_col3, #T_f3a5f_row0_col4, #T_f3a5f_row7_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f3a5f_row1_col0 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_f3a5f_row1_col1 {
#   background-color: #3a51a2;
#   color: #f1f1f1;
# }
# #T_f3a5f_row1_col2, #T_f3a5f_row5_col2 {
#   background-color: #333b97;
#   color: #f1f1f1;
# }
# #T_f3a5f_row1_col3, #T_f3a5f_row2_col2, #T_f3a5f_row5_col3, #T_f3a5f_row6_col3 {
#   background-color: #323896;
#   color: #f1f1f1;
# }
# #T_f3a5f_row1_col4, #T_f3a5f_row2_col0, #T_f3a5f_row2_col1, #T_f3a5f_row2_col3, #T_f3a5f_row2_col4, #T_f3a5f_row3_col2, #T_f3a5f_row3_col3, #T_f3a5f_row3_col4, #T_f3a5f_row4_col2, #T_f3a5f_row4_col3, #T_f3a5f_row4_col4, #T_f3a5f_row5_col4, #T_f3a5f_row6_col4, #T_f3a5f_row7_col4 {
#   background-color: #313695;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #4169e1; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #ffa500; padding: 20px; border-radius: 20px; border: 7px solid #00ffff; width: 95%;">
#   <span style="font-weight: bold; color: #00ffff; animation: pulse 2s infinite;">Step 4: Let's Check for  </span>
#   <span style="font-style: italic; color: #8a2be2; animation: pulse 2s infinite;"> Null Values & Duplicated Records!! 🤔</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
len_col=len(df.columns)
colors=plt.cm.viridis(np.linspace(0,1,len_col))
mse.bar(df,color=colors)
plt.suptitle('the number of missing values in data ',size=25,color='red')
plt.show()

# %%
print(f"the number of duplicated in data : {df.duplicated().sum()}".title())
# Out:
# The Number Of Duplicated In Data : 0

# %%
# all columns
df.columns.to_list()
# Out:
# ['Date', 'SPX', 'GLD', 'USO', 'SLV', 'EUR/USD']

# %%
#Data types for features
df.dtypes
# Out:
# Date        object
# SPX        float64
# GLD        float64
# USO        float64
# SLV        float64
# EUR/USD    float64
# dtype: object

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #ffffff; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #2d3748; padding: 20px; border-radius: 20px; border: 7px solid #ff6347; width: 95%;">
#   <span style="font-weight: bold; color: #ffcc00; animation: pulse 2s infinite;">Step 5: Data</span>
#   <span style="font-style: italic; color: #40e0d0; animation: pulse 2s infinite;"> Exploration 📊</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
col=df.select_dtypes(np.number).columns.to_list()
def histogram_visualization(int_col):
    n_c=3
    n_r=(len(int_col)+n_c-1)//n_c
    plt.figure(figsize=(20,15))
    for i,col in enumerate(int_col):
        plt.subplot(n_r,n_c,i+1)
        sns.histplot(data=df,x=col,kde=True)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
    plt.suptitle('Distribution of Numeric Data',color='red',size=25)
    plt.show()
histogram_visualization(col)

# %%
def pairplot(data):
        
    sns.pairplot(df) 
    plt.suptitle('Relationships Between Numerical Features')
    plt.show()

# %%
col=df.select_dtypes(np.number).columns.to_list()
def box_plot(int_col):
    n_c=3
    n_r=(len(int_col)+n_c-1)//n_c
    plt.figure(figsize=(20,15))
    for i,col in enumerate(int_col):
        plt.subplot(n_r,n_c,i+1)
        sns.boxplot(data=df,y=col)
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Frequency')
    plt.suptitle('Distribution of Numeric Data',color='red',size=25)
    plt.show()

box_plot(col)

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #7D3C98; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #F4D03F; padding: 20px; border-radius: 20px; border: 7px solid #1F618D; width: 95%;">
#   <span style="font-weight: bold; color: #3498DB; animation: pulse 2s infinite;">Step 6: Correlation </span>
#   <span style="font-style: italic; color: #E74C3C; animation: pulse 2s infinite;"> Analysis 📊</span>
# </p>

# %%
correlation=df.select_dtypes(np.number).corr()
plt.figure(figsize=(12,5))
sns.heatmap(correlation,annot=True,fmt=".2f",linewidth=.9)
plt.suptitle('Correlation Matrix of Numerical Features',color='red',size=15)
plt.show()

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #483D8B; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #8B0000; padding: 20px; border-radius: 20px; border: 7px solid #3CB371; width: 95%;">
#   <span style="font-weight: bold; color: #800080; animation: pulse 2s infinite;">Step 7: </span>
#   <span style="font-style: italic; color: #1E90FF; animation: pulse 2s infinite;"> Preprocessing 📊</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 2.5rem; color: #483D8B; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #FFD700; padding: 15px; border-radius: 15px; border: 5px solid #3CB371; width: 90%;">
#   <span style="font-weight: bold; color: #800080; animation: pulse 2s infinite;">Step 7.1: </span>
#   <span style="font-style: italic; color: #1E90FF; animation: pulse 2s infinite;"> Feature Engineering 🛠️</span>
# </p>
#
# <div style="font-family: 'Arial', sans-serif; background-color: #F0F8FF; border: 2px solid #1E90FF; padding: 15px; border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); margin-top: 15px; line-height: 1.8;">
#   <p style="color: #555; font-size: 1.2rem; margin: 0; text-align: justify;">
#     During this sub-step, we create a new feature, <b>‘year’</b>, by extracting the year value from the <b>‘Date’</b> column. This transformation enables a more detailed analysis of time-based patterns and trends within the dataset, helping to enhance predictive modeling.
#   </p>
# </div>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
# features engineering
df['year']=pd.to_datetime(df['Date']).dt.year

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Styled Text Box</title>
# <style>
#     body {
#         font-family: 'Poppins', sans-serif;
#         background-color: #1a202c; /* Dark background */
#         margin: 0;
#         padding: 20px;
#         color: #ffffff; /* Light text */
#     }
#     .styled-box {
#         max-width: 700px;
#         margin: 30px auto;
#         background: linear-gradient(145deg, #2d3748, #4a5568); /* Gradient effect */
#         border-radius: 15px;
#         padding: 25px;
#         box-shadow: 0px 8px 15px rgba(0, 0, 0, 0.3);
#     }
#     .styled-box h2 {
#         font-size: 24px;
#         color: #63b3ed; /* Soft blue */
#         text-align: center;
#         padding: 10px 0;
#         background-color: #2b6cb0; /* Blue bar behind heading */
#         border-radius: 10px;
#         margin: 0 auto 20px auto;
#         width: 60%;
#         box-shadow: 0px 4px 8px rgba(0, 0, 0, 0.2);
#     }
#     .styled-box p {
#         font-size: 18px;
#         line-height: 1.8;
#         text-align: justify;
#         color: #e2e8f0; /* Light gray text */
#         padding: 10px 20px;
#         background-color: #2d3748; /* Card inner color */
#         border-radius: 10px;
#         box-shadow: inset 0px 3px 6px rgba(0, 0, 0, 0.2);
#     }
# </style>
# </head>
# <body>
#
# <div class="styled-box">
#     <h2>Outliers</h2>
#     <p>
#         Outliers are data points that significantly differ from other values in a dataset. These values can be unusual or far from the general average of the data. Outliers can cause issues in statistical analyses and machine learning models if not properly addressed, potentially impacting the accuracy of results and data insights.
#     </p>
# </div>
#
# </body>
# </html>

# %%
def outlierspercentage(df):
    out_liers_precatege=[]
    columns=df.drop(columns=['Date'],axis=1).columns.to_list()
    for col in columns:
        q1=df[col].quantile(.25)
        q3=df[col].quantile(.75)
        iqr=q3-q1
        lower_bounds=q1-iqr*1.5
        upper_bounds=q3+iqr*1.5
        out_liers=df.loc[(df[col]<lower_bounds)|(df[col]>upper_bounds),col]
        out_liers_precatege.append(round(len(out_liers)/len(df)*100,2))

    sns.barplot(x=columns,y=out_liers_precatege,palette='Set3')
    for i,v in enumerate(out_liers_precatege):
        plt.text(i,v+.005,f"{v:.2f}%",ha='center',va='bottom',fontsize=10)
    plt.show()
outlierspercentage(df)

# %%
#handling out liers:
def handling_outliers(col):
    for col in col:
        q1=df[col].quantile(.25)
        q3=df[col].quantile(.75)
        iqr=q3-q1
        lower_bounds=q1-iqr*1.5
        upper_bounds=q3+iqr*1.5
        df[col]=np.where(df[col]<lower_bounds,lower_bounds,df[col])
        df[col]=np.where(df[col]>upper_bounds,upper_bounds,df[col])
col=df.select_dtypes(np.number).columns.to_list()
handling_outliers(col)

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #4169E1; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #00CED1; padding: 20px; border-radius: 20px; border: 7px solid #4682B4; width: 95%;">
#   <span style="font-weight: bold; color: #1E90FF; animation: pulse 2s infinite;">Step 8: Split </span>
#   <span style="font-style: italic; color: #87CEEB; animation: pulse 2s infinite;">Data ✂️</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>
# <div style="text-align:center">
#     <img src="https://miro.medium.com/v2/resize:fit:700/1*iZpmWiVeFn0bcuMZ_yiEdw.jpeg" alt="Image">
# </div>

# %%
x=df.drop(columns=['Date','GLD',])
y=df[['GLD']]
#train and test split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42,shuffle=True)

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #4B0082; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #FF6347; padding: 20px; border-radius: 20px; border: 7px solid #FFD700; width: 95%;">
#   <span style="font-weight: bold; color: #800080; animation: pulse 2s infinite;">Step 9: </span>
#   <span style="font-style: italic; color: #1E90FF; animation: pulse 2s infinite;">Modeling </span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>

# %%
models={LinearRegression.__name__:LinearRegression(),
       Ridge.__name__:Ridge(),
       Lasso.__name__:Lasso(),
      RandomForestRegressor.__name__:RandomForestRegressor(),
     GradientBoostingRegressor.__name__:GradientBoostingRegressor(),
     BaggingRegressor.__name__:BaggingRegressor(),
    AdaBoostRegressor.__name__:AdaBoostRegressor() }
def use_models (models,X_train,X_test,y_train,y_test):
    df_result=pd.DataFrame(columns=['name_model','r2_score','mse','score_train','score_test'])
    for name,model in models.items():
        model.fit(X_train,y_train)
        y_predict=model.predict(X_test)
        r_score=r2_score(y_test,y_predict)
        mse=np.sqrt(mean_squared_error(y_test,y_predict))
        score_train=model.score(X_train,y_train)
        score_test=model.score(X_test,y_test)
        df_result=pd.concat([df_result,pd.DataFrame({'name_model':[name],'r2_score':[r_score],'mse':[mse],'score_train':[score_train],'score_test':[score_test]})],ignore_index=True)
    return df_result
df_result=use_models(models,X_train,X_test,y_train,y_test)
df_result=df_result.sort_values(by='r2_score',ascending=False)

# %%
df_result
# Out:
#                   name_model  r2_score       mse  score_train  score_test
# 5           BaggingRegressor  0.991501  2.116336     0.998734    0.991501
# 3      RandomForestRegressor  0.990795  2.202481     0.999145    0.990795
# 4  GradientBoostingRegressor  0.986826  2.634947     0.992135    0.986826
# 1                      Ridge  0.941214  5.566008     0.928756    0.941214
# 0           LinearRegression  0.941209  5.566245     0.928758    0.941209
# 6          AdaBoostRegressor  0.938146  5.709417     0.939750    0.938146
# 2                      Lasso  0.936785  5.771863     0.921895    0.936785

# %%
metrics = ['r2_score', 'mse', 'score_train', 'score_test']

plt.figure(figsize=(16, 10))

# Create subplots for each metric
for i , col in enumerate(metrics,1):
    plt.subplot(2,2,i)
    sns.barplot(data=df_result,x=col,y='name_model',palette='viridis')
    plt.xlabel(col.replace('_',' ').title())
    plt.ylabel('Model Name')
    plt.title(f'{col.replace("_", " ").title()} for Different Regressors', fontsize=14)

plt.tight_layout()    
plt.show()

# %%
model=RandomForestRegressor()
model.fit(X_train,y_train)
# input_data = list(map(float, input('Enter SPX, USO, SLV, EUR/USD, year (separated by spaces): ').split()))
def prediction_gld(input_data):
    try:

        input_array = np.array(input_data).reshape(1, -1)

        prediction = model.predict(input_array)

        return (f"The predicted value is: {prediction[0]}")
    except ValueError as e:
        return (e)
input_data=[1447.160034	,72.998754,15.1800,1.471692,2008.0]
prediction_gld(input_data)
# Out:
# 'The predicted value is: 84.97500014999997'

# %%
import joblib
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %% [markdown]
# <p style="font-family: 'Amiri', serif; font-size: 3rem; color: #800080; text-align: center; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); background-color: #6495ED; padding: 20px; border-radius: 20px; border: 7px solid #FFD700; width: 95%;">
#   <span style="font-weight: bold; color: #800080; animation: pulse 2s infinite;">  Thank you for visiting my Notebook 💗 </span>
#   <span style="font-weight: bold; color: #9B59B6; animation: pulse 2s infinite;"">  if you find it helpful please consider giving it an upvote 👍</span>
# </p>
#
# <style>
# @keyframes pulse {
#   0% {
#     transform: scale(1);
#   }
#   50% {
#     transform: scale(1.05);
#   }
#   100% {
#     transform: scale(1);
#   }
# }
# </style>
